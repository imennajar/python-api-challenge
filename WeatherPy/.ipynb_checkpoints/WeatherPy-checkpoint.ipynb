# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
from scipy.stats import linregress
import scipy

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 586

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list

# %%
# Set the API base URL

api_key = weather_api_key

url  =f'http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units=metric&q='

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url+city

   
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather= requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date

        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind =city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date =city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | west island
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | lihue
# Processing Record 5 of Set 1 | uturoa
# Processing Record 6 of Set 1 | belyy yar
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | vila franca do campo
# Processing Record 9 of Set 1 | margaret river
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | wailua homesteads
# Processing Record 12 of Set 1 | nikolayevsk-on-amure
# Processing Record 13 of Set 1 | edinburgh of the seven seas
# Processing Record 14 of Set 1 | launceston
# Processing Record 15 of Set 1 | copiapo
# Processing Record 16 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 17 of Set 1 | invercargill
# Processing Record 18 of Set 1 | kuta
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | eirunepe
# Processing Record 21 of Set 1 | bel ombre
# Processing Record 22 of Set 1 | san antonio de pale
# Processing Record 23 of Set 1 | chegdomyn
# Processing Record 24 of Set 1 | grytviken
# Processing Record 25 of Set 1 | fale old settlement
# Processing Record 26 of Set 1 | klyuchi
# Processing Record 27 of Set 1 | kone
# Processing Record 28 of Set 1 | adamstown
# Processing Record 29 of Set 1 | blackmans bay
# Processing Record 30 of Set 1 | constantia
# Processing Record 31 of Set 1 | gadzhiyevo
# Processing Record 32 of Set 1 | harnai
# Processing Record 33 of Set 1 | saint-pierre
# Processing Record 34 of Set 1 | crockett
# Processing Record 35 of Set 1 | hadibu
# Processing Record 36 of Set 1 | tezu
# Processing Record 37 of Set 1 | port mathurin
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | bangor
# Processing Record 40 of Set 1 | lithgow
# Processing Record 41 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 42 of Set 1 | ulaangom
# Processing Record 43 of Set 1 | gobabis
# Processing Record 44 of Set 1 | geraldton
# Processing Record 45 of Set 1 | port lincoln
# Processing Record 46 of Set 1 | pangody
# Processing Record 47 of Set 1 | saipan
# Processing Record 48 of Set 1 | anadyr
# Processing Record 49 of Set 1 | puerto natales
# Processing Record 50 of Set 1 | dzhalagash
# Processing Record 0 of Set 2 | alice springs
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | xique xique
# Processing Record 3 of Set 2 | tonghae
# Processing Record 4 of Set 2 | kvissleby
# Processing Record 5 of Set 2 | umm al quwain city
# Processing Record 6 of Set 2 | iskateley
# Processing Record 7 of Set 2 | mawlamyinegyunn
# Processing Record 8 of Set 2 | qarqaraly
# Processing Record 9 of Set 2 | la'ie
# Processing Record 10 of Set 2 | tiksi
# Processing Record 48 of Set 4 | st. john's
# Processing Record 49 of Set 4 | longyearbyen
# Processing Record 0 of Set 5 | remire-montjoly
# Processing Record 1 of Set 5 | horsham
# Processing Record 2 of Set 5 | kapuskasing
# Processing Record 3 of Set 5 | tobelo
# Processing Record 4 of Set 5 | pittsburg
# Processing Record 5 of Set 5 | camana
# Processing Record 6 of Set 5 | afaahiti
# Processing Record 7 of Set 5 | glace bay
# Processing Record 8 of Set 5 | shimoda
# Processing Record 9 of Set 5 | kachia
# Processing Record 10 of Set 5 | labytnangi
# Processing Record 11 of Set 5 | fort frances
# Processing Record 12 of Set 5 | tolanaro
# Processing Record 13 of Set 5 | puerto baquerizo moreno
# Processing Record 14 of Set 5 | weno
# Processing Record 15 of Set 5 | fada
# Processing Record 16 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 17 of Set 5 | east tamworth
# Processing Record 18 of Set 5 | codo
# Processing Record 19 of Set 5 | kuala belait
# Processing Record 20 of Set 5 | punta arenas
# Processing Record 21 of Set 5 | nepalgunj
# Processing Record 22 of Set 5 | iguatemi
# Processing Record 23 of Set 5 | matai
# Processing Record 24 of Set 5 | sachin
# Processing Record 25 of Set 5 | kiunga
# Processing Record 26 of Set 5 | port augusta
# Processing Record 27 of Set 5 | aykhal
# Processing Record 28 of Set 5 | cine
# Processing Record 29 of Set 5 | jalai nur
# Processing Record 30 of Set 5 | tura
# Processing Record 31 of Set 5 | urangan
# Processing Record 32 of Set 5 | nar'yan-mar
# Processing Record 33 of Set 5 | mentougou
# Processing Record 34 of Set 5 | mount isa
# Processing Record 35 of Set 5 | albu kamal
# Processing Record 36 of Set 5 | kavieng
# Processing Record 37 of Set 5 | nishinoomote
# Processing Record 38 of Set 5 | zaragoza
# Processing Record 39 of Set 5 | lazaro cardenas
# Processing Record 40 of Set 5 | victorica
# Processing Record 41 of Set 5 | vallenar
# Processing Record 42 of Set 5 | vernon
# Processing Record 43 of Set 5 | aasiaat
# Processing Record 44 of Set 5 | kunduz
# Processing Record 45 of Set 5 | keflavik
# Processing Record 46 of Set 5 | utrik
# Processing Record 47 of Set 5 | hawaiian paradise park
# Processing Record 48 of Set 5 | udangudi
# Processing Record 49 of Set 5 | morant bay
# Processing Record 0 of Set 6 | kununurra
# Processing Record 1 of Set 6 | fort bragg
# Processing Record 2 of Set 6 | sitka
# Processing Record 3 of Set 6 | saacow
# Processing Record 4 of Set 6 | moussoro
# Processing Record 5 of Set 6 | sandnessjoen
# Processing Record 6 of Set 6 | katsuura
# Processing Record 7 of Set 6 | minas de marcona
# Processing Record 8 of Set 6 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 9 of Set 6 | princeville
# Processing Record 10 of Set 6 | tamanrasset
# Processing Record 11 of Set 6 | lodja
# Processing Record 12 of Set 6 | khilok
# Processing Record 13 of Set 6 | mulayjah
# Processing Record 14 of Set 6 | malango
# Processing Record 15 of Set 6 | saint-philippe
# Processing Record 16 of Set 6 | ulsteinvik
# Processing Record 17 of Set 6 | huanggang
# Processing Record 18 of Set 6 | stephenville
# Processing Record 19 of Set 6 | lorengau
# Processing Record 20 of Set 6 | le lavandou
# Processing Record 21 of Set 6 | daru
# Processing Record 22 of Set 6 | acajutla
# Processing Record 23 of Set 6 | kinablangan
# Processing Record 24 of Set 6 | sankeshwar
# Processing Record 25 of Set 6 | alta
# Processing Record 26 of Set 6 | villa gesell
# Processing Record 27 of Set 6 | touros
# Processing Record 28 of Set 6 | taguatinga
# Processing Record 29 of Set 6 | afif
# Processing Record 30 of Set 6 | cabedelo
# Processing Record 31 of Set 6 | altay
# Processing Record 32 of Set 6 | libertad
# Processing Record 33 of Set 6 | al artawiyah
# Processing Record 34 of Set 6 | fukuecho
# Processing Record 35 of Set 6 | nabire
# Processing Record 36 of Set 6 | agat village
# Processing Record 37 of Set 6 | itoman
# Processing Record 38 of Set 6 | rathenow
# Processing Record 39 of Set 6 | chonchi
# Processing Record 40 of Set 6 | thinadhoo
# Processing Record 41 of Set 6 | fort smith
# Processing Record 42 of Set 6 | saint-francois
# Processing Record 43 of Set 6 | tandalti
# Processing Record 44 of Set 6 | ola
# Processing Record 45 of Set 6 | kourou
# Processing Record 46 of Set 6 | tadine
# Processing Record 47 of Set 6 | assab
# Processing Record 48 of Set 6 | fort st. john
# Processing Record 49 of Set 6 | waitara
# Processing Record 0 of Set 7 | mammoth lakes
# Processing Record 1 of Set 7 | marsa alam
# Processing Record 2 of Set 7 | loukhi
# Processing Record 3 of Set 7 | jiuquan
# Processing Record 4 of Set 7 | inhambane
# Processing Record 5 of Set 7 | haiku-pauwela
# Processing Record 6 of Set 7 | akrehamn
# Processing Record 7 of Set 7 | juye
# Processing Record 8 of Set 7 | kamaishi
# Processing Record 9 of Set 7 | punta gorda
# Processing Record 10 of Set 7 | crane
# Processing Record 11 of Set 7 | rongelap
# Processing Record 12 of Set 7 | east london
# Processing Record 13 of Set 7 | abaza
# Processing Record 14 of Set 7 | mount gambier
# Processing Record 15 of Set 7 | zhangatas
# Processing Record 16 of Set 7 | kirensk
# Processing Record 17 of Set 7 | arawa
# Processing Record 18 of Set 7 | buka
# Processing Record 19 of Set 7 | port douglas
# Processing Record 20 of Set 7 | saint-paul
# Processing Record 21 of Set 7 | kabala
# Processing Record 22 of Set 7 | holualoa
# Processing Record 23 of Set 7 | saudarkrokur
# Processing Record 24 of Set 7 | red hill

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          588
# Lat           588
# Lng           588
# Max Temp      588
# Humidity      588
# Cloudiness    588
# Wind Speed    588
# Country       588
# Date          588
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Display sample data
# ----> 2 city_data_df.head()
#
# NameError: name 'city_data_df' is not defined

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  stanley  54.8680   -1.6985     15.50        90          75
# 1                adamstown -25.0660 -130.1015     19.74        60          47
# 2               constantia  44.1833   28.6500     15.39        71           0
# 3                   shingu  33.7333  135.9833     29.86        69          66
# 4        port-aux-francais -49.3500   70.2167      4.78        92         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.03      GB  1690508157
# 1              1.45      PN  1690508157
# 2              6.22      RO  1690508157
# 3              2.65      JP  1690508157
# 4              7.81      TF  1690508157

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

lat=city_data_df['Lat']
temp=city_data_df['Max Temp']
t=datetime.date.today()


plt.scatter(lat, temp, marker='o', facecolors='red', edgecolors='yellow',alpha=1)
# Incorporate the other graph properties
plt.title( f'City Latitude vs. Max Temperature({t})\n')
plt.ylabel('Max Temperature (C)')
plt.xlabel(' Latitude')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
lat=city_data_df['Lat']
hum=city_data_df['Humidity']
t= datetime.date.today()
plt.scatter(lat, hum, marker='v', facecolors='blue', edgecolors='yellow',alpha=0.75)
# Incorporate the other graph properties
plt.title( f'City Latitude vs Humidity ({t}) \n')
plt.ylabel('Humidity(%)')
plt.xlabel(' Latitude')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs.Cloudiness
lat=city_data_df['Lat']
cl=city_data_df['Cloudiness']
t= datetime.date.today()
plt.scatter(lat, cl, marker='s', facecolors='gray', edgecolors='yellow',alpha=0.75)
# Incorporate the other graph properties
plt.title( f'City Latitude vs. Cloudiness({t})\n')
plt.ylabel('Cloudiness(%)')
plt.xlabel(' Latitude')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. Wind Speed
# Build the scatter plots for latitude vs.Cloudiness
lat=city_data_df['Lat']
wind=city_data_df['Cloudiness']
t= datetime.date.today()
plt.scatter(lat, wind, marker='d', facecolors='green', edgecolors='yellow',alpha=0.75)
# Incorporate the other graph properties
plt.title( f'City Latitude vs. Wind Speed({t})\n')
plt.ylabel('Wind Speed(m/s)')
plt.xlabel(' Latitude')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def regress_value(x_values, y_values,title,coordinats):
    r = scipy.stats.pearsonr(x_values, y_values)
    print(f"The r-value is: {r[0]}")
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    regress_values= x_values*slope+intercept
    
    line_eq='y='+str(round(slope,2))+'x+'+ str(round(intercept,2))
    plt.plot(x_values,regress_values,'green')
    plt.annotate(line_eq, coordinats,fontsize=15,color='red')
    
    plt.scatter(x_values, y_values, marker='o', facecolors='blue', edgecolors='gray',alpha=0.75)
    
    plt.ylabel(title)
    
    plt.xlabel('Latitude')

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>0]
# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           stanley  54.8680   -1.6985     15.50        90          75
# 2        constantia  44.1833   28.6500     15.39        71           0
# 3            shingu  33.7333  135.9833     29.86        69          66
# 5          la ronge  55.1001 -105.2842     17.14        45          40
# 8         jamestown  42.0970  -79.2353     20.95        94          40
#
#          Wind Speed Country        Date
# City_ID
# 0              1.03      GB  1690508157
# 2              6.22      RO  1690508157
# 3              2.65      JP  1690508157
# 5              5.14      CA  1690508157
# 8              3.60      US  1690508158

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]
# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                adamstown -25.0660 -130.1015     19.74        60          47
# 4        port-aux-francais -49.3500   70.2167      4.78        92         100
# 6                  chonchi -42.6128  -73.8092     10.07        99         100
# 7                geraldton -28.7667  114.6000     13.23        94          75
# 11           blackmans bay -43.0167  147.3167     15.41        58           0
#
#          Wind Speed Country        Date
# City_ID
# 1              1.45      PN  1690508157
# 4              7.81      TF  1690508157
# 6              2.01      CL  1690508157
# 7              2.06      AU  1690507888
# 11             4.03      AU  1690508158

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %% [markdown]
# ##### Temperature vs. Latitude Linear Regression Plot in the Northern Hemisphere

# %%
# Linear regression on Northern Hemisphere
lat=northern_hemi_df['Lat']
temp=northern_hemi_df['Max Temp']
# Call the function
regress_value(lat,temp,'Max Temperaure',(5,10))
# Out:
# The r-value is: -0.6069192062212571

# %% [markdown]
# ##### Temperature vs. Latitude Linear Regression Plot in the Southern Hemisphere

# %%
# Linear regression on Southern Hemisphere

lat=southern_hemi_df['Lat']
temp=southern_hemi_df['Max Temp']
# Call the function
regress_value(lat,temp,'Max Temperaure',(-30,5))
# Out:
# The r-value is: 0.8098872305202918

# %% [markdown]
# **Discussion about the linear relationship:
# - There is a negative correlation between temperature and latitude with a negative correlation coefficient in the Northern Hemisphere.
# - The r-value is between -0.7 and -0.5. The Temperature and Latitude are considered moderately correlated in the Northern Hemisphere.
#
# - There is a positive correlation between temperature and latitude with a positive correlation coefficient in the Southern Hemisphere.
#
# - The r-value is higher than 0.7. The Temperature and Latitude are considered highly correlated in the Northern Hemisphere.
#
# ##### Example of Max temperatures in cities in the Southern Hemisphere on 7/27/23 :
#
# Map that displays a point for some cities on Southern Hemisphere. The size of the points represents the Max temperature in each city.
#
# <img src='output_data/lat.temp.png' style ='width:700px;height:300px'/>
# When we get closer to the equator (latitude = 0), the size of the points becomes bigger.
#
# -->Temperature is inversely related to latitude. As latitude increases, the temperature falls, and vice versa. Generally, around the world, it gets warmer towards the equator and cooler towards the poles

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %% [markdown]
# ##### Humidity vs. Latitude Linear Regression Plot in the Northern Hemisphere

# %%
# Linear regression on Northern Hemisphere

lat=northern_hemi_df['Lat']
hum=northern_hemi_df['Humidity']
# Call the function
regress_value(lat,hum,'Humidity(%)',(50,20))
# Out:
# The r-value is: -0.016062532791883

# %% [markdown]
# ##### Humidity vs. Latitude Linear Regression Plot in the Southern Hemisphere

# %%
# Linear regression on southern Hemisphere

lat=southern_hemi_df['Lat']
hum=southern_hemi_df['Humidity']
# Call the function
regress_value(lat,hum,'Humidity(%)',(-48,30))
# Out:
# The r-value is: -0.03232664373880373

# %% [markdown]
# **Discussion about the linear relationship:
#
# - The correlation between Humidity and Latitude is close to 0 in the Northern Hemisphere and Southern Hemisphere.
#
# - The r-value is not significant. There is no correlation between Humidity and Latitude in the Northern Hemisphere and Southern Hemisphere.
#
# - r- value is not significant; a regression analysis should never be done.
#
# ##### Example of Humidity in cities in the Southern Hemisphere on 7/27/23:
#
# Map that displays a point for some cities in the Southern Hemisphere. The size of the points represents the Humidity in each city.
#
# <img src='output_data/lat.hum.png' style ='width:700px;height:300px'/>
# The size of the points isn't dependent on the location as it relates to the equator.
#
# --> Relative humidity is maximum near the equator, but decreases in subtropical areas and increases again in temperate regions.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %% [markdown]
# ##### Cloudiness vs. Latitude Linear Regression Plot in the Northern Hemisphere

# %%
# Linear regression on Northern Hemisphere

lat=northern_hemi_df['Lat']
cl=northern_hemi_df['Cloudiness']
# Call the function
regress_value(lat,cl,'Cloudiness(%)',(2,2))
# Out:
# The r-value is: -0.051457933906938765

# %% [markdown]
# ##### Cloudiness vs. Latitude Linear Regression Plot in the Southern Hemisphere

# %%
# Linear regression on Northern Hemisphere

lat=southern_hemi_df['Lat']
cl=southern_hemi_df['Cloudiness']
# Call the function
regress_value(lat,cl,'Cloudiness(%)',(-50,25))
# Out:
# The r-value is: -0.13964852640816425

# %% [markdown]
# **Discussion about the linear relationship
#
# - The correlation between Humidity and Latitude is close to 0 in the Northern Hemisphere and Southern Hemisphere.
#
# - The r-value is not significant. There is no correlation between Humidity and Latitude in the Northern Hemisphere and Southern Hemisphere.
#
# - r- value is not significant; a regression analysis should never be done.
#
# ##### Example of Cloudiness in cities in the Southern Hemisphere on 7/27/23 :
#
# Map that displays a point for some cities in the Southern Hemisphere. The size of the points represents the Cloudiness in each city.
#
# <img src='output_data/lat.cl.png' style ='width:700px;height:300px'/>
# The size of the points isn't dependent on the location as it relates to the equator.
#
# --> Cloudiness is not related to latitude. There is a high degree of variance in cloudiness across all latitudes, suggesting that latitude does not cause an area to be more or less cloudy.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %% [markdown]
# ##### Wind Speed vs. Latitude Linear Regression Plot in the Northern Hemisphere

# %%
# Linear regression on Northern Hemisphere

lat=northern_hemi_df['Lat']
wind=northern_hemi_df['Wind Speed']
# Call the function
regress_value(lat,wind,'Wind Speed(m/s)',(10,14))
# Out:
# The r-value is: -0.22708538832193342

# %% [markdown]
# ##### Wind Speed vs. Latitude Linear Regression Plot in the Southern Hemisphere

# %%
#Linear regression on Sourthern Hemisphere

lat=southern_hemi_df['Lat']
wind=southern_hemi_df['Wind Speed']
# Call the function
regress_value(lat,wind,'Wind Speed(m/s)',(-50,15))
# Out:
# The r-value is: -0.0009406707029431735

# %% [markdown]
# **Discussion about the linear relationship:
#
# The correlation between Wind Speed and Latitude is very weak on Northern Hemisphere and Southern Hemisphere.
# The r-value is between -0.2 and 0. There is a very weak negative correlation between Wind Speed and Latitude on Northern Hemisphere and Southern Hemisphere.
#
# ##### Example of Wind Speed in cities in the Southern Hemisphere on 7/27/23:
#
# Map that displays a point for some cities in the Southern Hemisphere. The size of the points represents the Wind speed in each city.
#
# <img src='output_data/lat.wind.png' style ='width:700px;height:300px'/>
# The size of the points is not dependent on the location as it relates to the equator
#
# --> The latitude can impact the direction of the wind, not the speed.
